# %%
import tweepy
import wordcloud
from textblob import TextBlob
import re
import spacy

# %%
api_key = "btZzNAPzYRVauFxGZp0ylCiWq"
api_secret = "uAatv7uLAqG1nkgad180vtaw1P2aTp4hH7QOrsDtZa3R2d97Cv"
access_token = "857530568-NtMnTwJbeAUsBJ75akfvUlFyU8WSEvoXxxZOeJqy"
access_token_secret = "TBV1OofYaYVBR20T7lLUQplVqzbkVFOgmRGlF2OG9nn3e"

# %%
auth = tweepy.OAuthHandler(api_key,api_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %%
tweets = api.search(q="Reliance jio",count=20,tweet_mode="extended")

# %% [raw]
# for tw in tweets:
#     print(tw.full_text)
#     print("\n")

# %%
sents = []
clean_tweets = []

for tw in tweets:
    tw = tw.full_text
    tw = re.sub("@[a-zA-Z0-9:_]+","",tw) # remove handles
    tw = re.sub("#","",tw) # remove #
    tw = re.sub("RT","",tw)
    tw = re.sub("http[a-zA-Z0-9._\/:\%]+","",tw) # to remove urls
    tw = tw.strip() # to remove whitespace from end and begining of text
    print(tw)
    if len(tw)>10:
        tw = TextBlob(tw)
        if tw.detect_language()!='en':
            tw = tw.translate(to='en')
            print(tw.raw)
        clean_tweets.append(tw.raw)
        if tw.sentiment.polarity>+0.1:
            print("Positive")
            sents.append("Positive")
        elif tw.sentiment.polarity<-0.1:
            print("Negative")
            sents.append("Negative")
        else:
            print("Neutral")
            sents.append("Neutral")
        print("****************************")
        print("\n")
# Out:
# Impressive in a graph, but the cash-burning / scorched earth strategy used by Reliance Jio in India isn’t really a fair com…
# Impressive in a graph, but the cash-burning / scorched earth strategy used by Reliance Jio in India isn’t really a fair com…
# Positive
# ****************************
#
#
# Sh.  Chairman/CEC  inaugurates 4G Mobile Tower in one of the remotest village Fotoksar in Leh under…
# Sh.  Chairman/CEC  inaugurates 4G Mobile Tower in one of the remotest village Fotoksar in Leh under…
# Neutral
# ****************************
#
#
# Work From Home Plans: घर से कर रहे हैं ऑफिस का काम और चाहिए ज्यादा डाटा, देखें Airtel-Jio-Vi के ये प्लान्स
#
#
#
# WorkFromHomePlans Jio Airtel Vodafone PrepaidPlans
# Work From Home Plans: Doing office work from home and need more data, see these Airtel-Jio-Vi plans
#
#
#
# WorkFromHomePlans Jio Airtel Vodafone PrepaidPlans
# Positive
# ****************************
#
#
# 8 रुपये में 1GB डेटा और 90 दिनों की वैलिडिटी, क्या आपने देखा reliancejio का ये बेस्ट प्रीपेड प्लान? ... Jio
# 1GB data and 90 days validity for 8 rupees, have you seen this best prepaid plan of reliancejio? ... Jio
# Positive
# ****************************
#
#
# strange,Reliance jio is not even covered by 15km from Hyderabad?
# strange,Reliance jio is not even covered by 15km from Hyderabad?
# Neutral
# ****************************
#
#
# Google Cloud could potentially earn over $1 Bn in revenue from its deal with India's 🇮🇳 Reliance Jio, making the part…
# Google Cloud could potentially earn over $1 Bn in revenue from its deal with India's 🇮🇳 Reliance Jio, making the part…
# Neutral
# ****************************
#
#
# A new report indicates that Reliance and Google might establish their manufacturing plant for the JioPhone Next in Gujara…
# A new report indicates that Reliance and Google might establish their manufacturing plant for the JioPhone Next in Gujara…
# Neutral
# ****************************
#
#
# Google Cloud could potentially earn over $1 Bn in revenue from its deal with India's 🇮🇳 Reliance Jio, making the part…
# Google Cloud could potentially earn over $1 Bn in revenue from its deal with India's 🇮🇳 Reliance Jio, making the part…
# Neutral
# ****************************
#
#
# A new report indicates that Reliance and Google might establish their manufacturing plant for the JioPhone Next in Gujarat.
# A new report indicates that Reliance and Google might establish their manufacturing plant for the JioPhone Next in Gujarat.
# Neutral
# ****************************
#
#
# Impressive in a graph, but the cash-burning / scorched earth strategy used by Reliance Jio in India isn’t really a fair comparison…   neither is Israel with their “kind geography” for a network rollout.
# Impressive in a graph, but the cash-burning / scorched earth strategy used by Reliance Jio in India isn’t really a fair comparison…   neither is Israel with their “kind geography” for a network rollout.
# Positive
# ****************************
#
#
# Anant Ambani takes seat on boards of RIL’s 2 new solar cos
#
# anantambani reliance jio mukeshambani switchbazaar elec…
# Anant Ambani takes seat on boards of RIL’s 2 new solar cos
#
# anantambani reliance jio mukeshambani switchbazaar elec…
# Positive
# ****************************
#
#
# Anant Ambani takes seat on boards of RIL’s 2 new solar cos
#
# anantambani reliance jio mukeshambani switchbazaar elec…
# Anant Ambani takes seat on boards of RIL’s 2 new solar cos
#
# anantambani reliance jio mukeshambani switchbazaar elec…
# Positive
# ****************************
#
#
# It is one of the largest telecom project service providers for Reliance Jio and is currently engaged in rolling out of 4G OFC Network services across Northern India.
# It is one of the largest telecom project service providers for Reliance Jio and is currently engaged in rolling out of 4G OFC Network services across Northern India.
# Neutral
# ****************************
#
#
# Anant Ambani takes seat on boards of RIL’s 2 new solar cos
#
# anantambani reliance jio mukeshambani switchbazaar elec…
# Anant Ambani takes seat on boards of RIL’s 2 new solar cos
#
# anantambani reliance jio mukeshambani switchbazaar elec…
# Positive
# ****************************
#
#
# Anant Ambani takes seat on boards of RIL’s 2 new solar cos
#
# anantambani reliance jio mukeshambani switchbazaar electrical b2b marketplace startup thinkbusiness thinkswitchbazaar switch2switchbazaar cleanenergy greenenergy renewableenergy
# Anant Ambani takes seat on boards of RIL’s 2 new solar cos
#
# anantambani reliance jio mukeshambani switchbazaar electrical b2b marketplace startup thinkbusiness thinkswitchbazaar switch2switchbazaar cleanenergy greenenergy renewableenergy
# Positive
# ****************************
#
#
# Reliance Jio Users Data Loan Free - How to avail
# Reliance Jio Users Data Loan Free - How to avail
# Positive
# ****************************
#
#
# Work From Home Plans: घर से कर रहे हैं ऑफिस का काम और चाहिए ज्यादा डाटा, देखें Airtel-Jio-Vi के ये प्लान्स
#
# …
# Work From Home Plans: Doing office work from home and need more data, see these Airtel-Jio-Vi plans
#
# …
# Positive
# ****************************
#
#
# jio Reliance भारत की नंबर वन कंपनी होने के बाद भी इतना घटिया काम कर रही है लोगों का डाटा चुरा रही है कुछ तो शर्म करो…
# Jio Reliance is doing such a poor job even after being India's number one company, stealing people's data, be ashamed of something…
# Negative
# ****************************
#
#
# Work From Home Plans: घर से कर रहे हैं ऑफिस का काम और चाहिए ज्यादा डाटा, देखें Airtel-Jio-Vi के ये प्लान्स
#
#
#
# WorkFromHomePlans Jio Airtel Vodafone PrepaidPlans
# Work From Home Plans: Doing office work from home and need more data, see these Airtel-Jio-Vi plans
#
#
#
# WorkFromHomePlans Jio Airtel Vodafone PrepaidPlans
# Positive
# ****************************
#
#
# 1GB data and 90 days validity for 8 rupees, did you see this best prepaid plan of Reliance Jio?
# 1GB data and 90 days validity for 8 rupees, did you see this best prepaid plan of Reliance Jio?
# Positive
# ****************************

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.figure(figsize=(12,5))
sns.countplot(sents)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Wordcloud analysis

# %%
df = pd.DataFrame({"tweets":clean_tweets,"sents":sents})
df.head()
# Out:
#                                               tweets     sents
# 0  Impressive in a graph, but the cash-burning / ...  Positive
# 1  Sh.  Chairman/CEC  inaugurates 4G Mobile Tower...   Neutral
# 2  Work From Home Plans: Doing office work from h...  Positive
# 3  1GB data and 90 days validity for 8 rupees, ha...  Positive
# 4  strange,Reliance jio is not even covered by 15...   Neutral

# %%
ptweets = df.tweets[df.sents=="Positive"].tolist()

wd = wordcloud.WordCloud(background_color='white',max_words=20,width=1200,height=600).generate_from_text(" ".join(ptweets))
plt.figure(figsize=(12,5))
plt.imshow(wd)
plt.show()

# %%
ntweets = df.tweets[df.sents=="Negative"].tolist()

wd = wordcloud.WordCloud(background_color='white',max_words=20,width=1200,height=600).generate_from_text(" ".join(ntweets))
plt.figure(figsize=(12,5))
plt.imshow(wd)
plt.show()

# %% [markdown]
# # NER Analysis

# %%
for tw in ptweets:
    doc = nlp(tw)
    displacy.render(doc,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Impressive in a graph, but the cash-burning / scorched earth strategy used by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reliance Jio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  isn’t really a fair com…</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Work From Home Plans: Doing office work from home and need more data, see these Airtel-Jio-Vi plans</br></br></br></br>
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WorkFromHomePlans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jio Airtel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Vodafone PrepaidPlans</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">1GB data and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     90 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  validity for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  rupees, have you seen this best prepaid plan of reliancejio? ...
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Impressive in a graph, but the cash-burning / scorched earth strategy used by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reliance Jio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  isn’t really a fair comparison…   neither is
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  with their “kind geography” for a network rollout.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anant Ambani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  takes seat on boards of RIL’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  new solar cos</br></br>anantambani reliance jio mukeshambani switchbazaar elec…</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anant Ambani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  takes seat on boards of RIL’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  new solar cos</br></br>anantambani reliance jio mukeshambani switchbazaar elec…</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anant Ambani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  takes seat on boards of RIL’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  new solar cos</br></br>anantambani reliance jio mukeshambani switchbazaar elec…</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anant Ambani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  takes seat on boards of RIL’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  new solar cos</br></br>anantambani reliance jio mukeshambani switchbazaar electrical b2b marketplace startup thinkbusiness thinkswitchbazaar switch2switchbazaar cleanenergy greenenergy renewableenergy</div></span>
# /opt/anaconda3/lib/python3.8/site-packages/spacy/displacy/__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Reliance Jio Users Data Loan Free - How to avail</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Work From Home Plans: Doing office work from home and need more data, see these Airtel-Jio-Vi plans</br></br>…</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Work From Home Plans: Doing office work from home and need more data, see these Airtel-Jio-Vi plans</br></br></br></br>
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WorkFromHomePlans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jio Airtel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Vodafone PrepaidPlans</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">1GB data and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     90 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  validity for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  rupees, did you see this best prepaid plan of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reliance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Jio?</div></span>

# %%
for tw in ntweets:
    doc = nlp(tw)
    displacy.render(doc,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jio Reliance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is doing such a poor job even after being
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's number
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  company, stealing people's data, be ashamed of something…</div></span>

# %% [markdown]
# # Text analytics with textblob

# %%
data = TextBlob("Hello Everyone, Hope you are enjoying Machine Learning.")

# %%
data.detect_language()
# Out:
# 'en'

# %%
data.translate(to='hi')
# Out:
# TextBlob("सभी को नमस्कार, आशा है कि आप मशीन लर्निंग का आनंद ले रहे होंगे।")

# %%
data.translate(to='mr')
# Out:
# TextBlob("प्रत्येकास अभिवादन, आशा आहे की आपण मशीन लर्निंगचा आनंद घेत असाल.")

# %%
data.translate(to='te')
# Out:
# TextBlob("అందరికీ హలో, మీరు యంత్ర అభ్యాసాన్ని ఆనందిస్తున్నారని ఆశిస్తున్నాను.")

# %%
data.translate(to='ka')
# Out:
# TextBlob("ყველას მოგესალმებით, იმედია გსიამოვნებთ მანქანური სწავლება.")

# %%
data.translate(to='bn')
# Out:
# TextBlob("সবাইকে হ্যালো, আশা করি আপনি মেশিন লার্নিং উপভোগ করছেন।")

# %%
data.translate(to='ta')
# Out:
# TextBlob("அனைவருக்கும் வணக்கம், நீங்கள் இயந்திர கற்றலை அனுபவிக்கிறீர்கள் என்று நம்புகிறேன்.")

# %%
data = TextBlob("the movie was amazing and i love it")
data.sentiment.polarity
# Out:
# 0.55

# %%
data = TextBlob("the movie was bad and i hate it")
data.sentiment.polarity
# Out:
# -0.75

# %% [markdown]
#    # NER - Named Entity Recognition

# %%
import spacy
from spacy import displacy

nlp = spacy.load('en_core_web_sm')
doc = nlp("John purchased a watch in Mumbai while working with State Bank of India and gifted to Cherry Kriston last monday.")


displacy.render(doc,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  purchased a watch in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  while working with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     State Bank of India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and gifted to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cherry Kriston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>

# %%
nlp?
